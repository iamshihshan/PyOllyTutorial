# %% [markdown]
# # Bokeh
# * Let's create interactive html graph wiht bokeh
# * [More examples](http://bokeh.pydata.org/en/latest/docs/gallery.html#gallery)
# * [More Tutorial 1](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/tree/master/tutorial/)
# * [More Tutorial 2](http://bokeh.pydata.org/en/latest/docs/user_guide.html)

# %%
from bokeh.io import output_notebook, show
output_notebook()
import pandas as pd
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6b12794e-792a-43ed-99b7-3c8c7202a405">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv(r'C:\Users\Olly\Downloads\Python\PyOlly\OllyPythonTutorial\DataBase\CSVData.csv')
df.head()
# Out:
#    ID             Date Country  Stars  CustomerNumber Status
# 0   1  2017/6/17 00:00     USA      6             143      R
# 1   2  2017/6/17 00:00  Canada      2              89      O
# 2   3  2017/6/17 00:00   Japan      6             123      I
# 3   4  2017/6/17 00:00  Taiwan      2             333      R
# 4   5  2017/6/17 00:00   Korea      3             133      R

# %% [markdown]
# # Change Defaults Width & Height

# %%
from bokeh.charts import defaults

defaults.width = 600
defaults.height = 300

# %% [markdown]
# # Histogram plot
# * Separate different group with **color**
# * Set **bins** for customize distance of frequency

# %%
from bokeh.charts import Histogram

# %%
hist = Histogram(df, values='Stars', color='Status', bins=3,
                 xlabel='Distribution of Stars', ylabel='Frequency of Stars',
                 title='Histogram Plot', legend='top_left')
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5e2a568c-34f9-4add-9526-e8d0edfab973"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5e2a568c-34f9-4add-9526-e8d0edfab973").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5e2a568c-34f9-4add-9526-e8d0edfab973");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5e2a568c-34f9-4add-9526-e8d0edfab973' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"63094d89-f564-4541-9d7f-b2624a6284d7":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f3cb521-c9b4-4770-8447-702f182cd857","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1fa6b41b-28d2-4166-89df-dd1e94eb2605","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2e92bc0f-3816-4dbb-929b-0967c4e2bd75","type":"Rect"},{"attributes":{"plot":{"id":"5d2e8f71-9118-4b94-a26b-28f8943a4d93","subtype":"Chart","type":"Plot"}},"id":"ac626444-3c64-4760-9b98-0c69c71cd429","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"ba67a152-8a48-49d8-9c30-85267fee9f5e","type":"ColumnDataSource"},"glyph":{"id":"15397102-3c7b-4926-8a41-1c67a1580ef7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"85c1fd9a-c522-4b98-a22c-0d7b93b59bbb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8fc01030-a3e4-4342-930a-6b8d3c2ac087","type":"ColumnDataSource"},"glyph":{"id":"d302605c-cfd2-4852-9fb7-3a3feaad613e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"da855093-00d8-4db0-976e-1d3f69b6efc4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"chart_index":["(6.3, 7.7]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[4.0],"label":["(6.3, 7.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.333333333333333],"x":["7.0"],"y":[2.0]}},"id":"8fc01030-a3e4-4342-930a-6b8d3c2ac087","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d302605c-cfd2-4852-9fb7-3a3feaad613e","type":"Rect"},{"attributes":{"plot":null,"text":"Histogram Plot"},"id":"017e129a-dff0-420b-b497-78f7bd120b6f","type":"Title"},{"attributes":{"data_source":{"id":"564b30d7-76b2-4c73-9740-036f7acfa59e","type":"ColumnDataSource"},"glyph":{"id":"7a16ea62-3880-40e5-98ae-377f90af245e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"13926a43-c8ef-4a10-8f52-8575689cbdad","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"chart_index":["[5.0, 6.3]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[3.0],"label":["[5.0, 6.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.333333333333333],"x":["5.65"],"y":[1.5]}},"id":"adc10063-3ab7-4e88-9417-fce839d174b3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8c860a8f-8682-4bb0-86d8-7e7463e56a1e","type":"Rect"},{"attributes":{"plot":{"id":"5d2e8f71-9118-4b94-a26b-28f8943a4d93","subtype":"Chart","type":"Plot"}},"id":"0c98a3c9-6d7b-4848-9e87-a43af1251ec2","type":"ResetTool"},{"attributes":{"label":{"value":"I"},"renderers":[{"id":"52a376b4-ad63-4fac-84da-ddb0ae6d38fc","type":"GlyphRenderer"},{"id":"da855093-00d8-4db0-976e- ...

# %% [markdown]
# # Scatter Plot
# * Separate different groups with **marker** & **color**

# %%
from bokeh.charts import Scatter

# %%
scatter = Scatter(df, x='Stars', y='CustomerNumber', marker='Country', color='Country',
                  xlabel="Stars", ylabel="Total Customer",
                  title="Scatter Plot", legend="top_left",
                  outline_line_color="gray",background_fill_color="pink",
                  width=700, height=300)
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1998484c-f538-4de3-8f30-26dc2a6f40ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1998484c-f538-4de3-8f30-26dc2a6f40ba").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1998484c-f538-4de3-8f30-26dc2a6f40ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1998484c-f538-4de3-8f30-26dc2a6f40ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0f0bcd23-b3dc-4f17-9c6c-83005575d3c3":{"roots":{"references":[{"attributes":{"callback":null,"end":1311.1,"start":-22.10000000000001},"id":"bf1d4d1e-ace1-45eb-9ae6-23c9c8d1b10b","type":"Range1d"},{"attributes":{"label":{"value":"Canada"},"renderers":[{"id":"4325f5ec-8b54-43bc-af74-f15fff5ef272","type":"GlyphRenderer"}]},"id":"3d74993f-04c1-400e-91ec-ef046e525a84","type":"LegendItem"},{"attributes":{"label":{"value":"Korea"},"renderers":[{"id":"b6a1c1cf-495b-4e26-b9b4-a3d2243c4c25","type":"GlyphRenderer"}]},"id":"2d4bb0d4-7cdc-454d-8ec9-5cdfcc232375","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"09e7370c-02d0-41d7-9795-90797561e071","type":"Circle"},{"attributes":{"data_source":{"id":"5671d0d6-d746-41be-ba98-3d9df8930523","type":"ColumnDataSource"},"glyph":{"id":"e04c9b79-540e-4727-817e-02bcba1b1b79","type":"InvertedTriangle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8c50a4b1-10a6-463d-a76d-d17946064ab1","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"63224625-5fa8-4331-9f1a-907dda391511","type":"ColumnDataSource"},"glyph":{"id":"7ec2b3b9-a6d5-4df1-9401-d7df96db342e","type":"X"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"350a600c-5565-43cc-8688-af33dace7fef","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"34bb8506-11f5-469b-b9bd-f83a38d2b953","subtype":"Chart","type":"Plot"}},"id":"c6d3d798-c424-47ab-8d25-e8adf733c6b8","type":"SaveTool"},{"attributes":{"data_source":{"id":"dec65331-8074-4457-90b6-dc38830d5f2f","type":"ColumnDataSource"},"glyph":{"id":"13df9de8-2bd3-4da3-9334-c1a424cdbe72","type":"Cross"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c8f37e2c-50ba-4dff-9174-87dc20a1ab0d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"34bb8506-11f5-469b-b9bd-f83a38d2b953","subtype":"Chart","type":"Plot"}},"id":"3400801d-9c5f-4f10-96bd-49c394f6ad61","type":"PanTool"},{"attributes":{"background_fill_color":{"value":"pink"},"below":[{"id":"bbef1b6a-13f0-43d6-8dd7-f358aecd3076","type":"LinearAxis"}],"height":300,"left":[{"id":"62192996-e2a3-44ef-87ad-30780573b368","type":"LinearAxis"}],"outline_line_color":{"value":"gray"},"renderers":[{"id":"983f3640-5a8f-4502-bf49-19c294e4d80e","type":"BoxAnnotation"},{"id":"350a600c-5565-43cc-8688-af33dace7fef","type":"GlyphRenderer"},{"id":"4325f5ec-8b54-43bc-af74-f15fff5ef272","type":"GlyphRenderer"},{"id":"8c50a4b1-10a6-463d-a76d-d17946064ab1","type":"GlyphRenderer"},{"id":"c8f37e2c-50ba-4dff-9174-87dc20a1ab0d","type":"GlyphRenderer"},{"id":"b6a1c1cf-495b-4e26-b9b4-a3d2243c4c25","type":"GlyphRenderer"},{"id":"ac6983af-96b4-4e77-a17b-7c1eb86e2535","type":"GlyphRenderer"},{"id":"97eca327-5a3c-44fb-8a68-266da8379120","type":"GlyphRenderer"},{"id":"8334202f-88ac-431d-9a20-7480b5295a94","type":"GlyphRenderer"},{"id":"cf7b3cf8-e9a6-4889-b0e4-6816cc0c1457","type":"Legend"},{"id":"bbef1b6a-13f0-43d6-8dd7-f358aecd3076","type":"LinearAxis"},{"id":"62192996-e2a3-44ef-87ad-30780573b368","type":"LinearAxis"},{"id":"b0fee341-ba9e-47d9-8902-ce0c9d19e0e9","type":"Grid"},{"id":"84345e71-232c-486d-8a31-3461cbde1792","type":"Grid"}],"title":{"id":"403c707d-fe0d-40a7-915c-08686389863d","type":"Title"},"tool_events":{"id":"459e307e-9447-4920-8b8a-0b1d98950bf1","type":"ToolEvents"},"toolbar":{"id":"c4f20cc2-d7fb-46ed-a743-13b2202cd134","type":"Toolbar"},"width":700,"x_mapper_type":"auto","x_range":{"id":"3f466020-f623-46f1-9c83-f7390a975378","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"bf1d4d1e-ace1-45eb-9ae6-23c9c8d1b10b","type":"Range1d"}},"id":"34bb8506-11f5-469b-b9bd-f83a38d2b953","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"e769c2b3-58fb-4493-b733-5a475ee57554","type":"ColumnDataSource"},"glyph":{"id":"773184bb-9d8e-438e-852f-533ebe757114","type":"Asterisk" ...

# %% [markdown]
# # Bar Plot
# * Separate differnt group with **label** & **group** (**color**)
# * Aggregate what you need with **agg**

# %%
from bokeh.charts import Bar

# %%
bar = Bar(df, values='CustomerNumber', label='Country', agg='sum', group='Status', color='Status',
          xlabel='Country', ylabel="Mean of CustomerNumber",
          title="Bar Chart", legend="top_right",
          outline_line_color="gray",background_fill_color="black",
          width=800, height=300)
show(bar)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="440b5ff5-6cdd-41ae-80f4-0dc612e05c33"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#440b5ff5-6cdd-41ae-80f4-0dc612e05c33").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("440b5ff5-6cdd-41ae-80f4-0dc612e05c33");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '440b5ff5-6cdd-41ae-80f4-0dc612e05c33' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"13efd17d-7482-49c2-b9bb-e31eb859caf8":{"roots":{"references":[{"attributes":{"data_source":{"id":"7f501c2b-c93e-4175-8577-d8c677a8e557","type":"ColumnDataSource"},"glyph":{"id":"ecb6333b-f45f-4a1b-886b-e85a376a6ee9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b3d41ccf-8101-4060-aed9-9313db2b6ea3","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Australia","Canada","England","Iceland","Japan","Korea","Taiwan","USA"]},"id":"5411a9c0-141b-436b-83ba-6712912b5ba1","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"Country":["Iceland"],"Status":["I"],"chart_index":[{"Country":"Iceland","Status":"I"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1818.0],"label":[{"Country":"Iceland","Status":"I"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["Iceland:0.75"],"y":[909.0]}},"id":"badc0cd9-2dab-42e8-98f8-416469e80047","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ecb6333b-f45f-4a1b-886b-e85a376a6ee9","type":"Rect"},{"attributes":{"data_source":{"id":"ca057fb0-3e53-4ce9-9142-5f85f3abc45e","type":"ColumnDataSource"},"glyph":{"id":"5a4e8f2f-c540-497f-9113-be058dc37e54","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3c975b76-afd6-401b-940f-e90b5abe224c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"aa3d323d-94ff-46a2-bcc6-df8cbafcfa15","subtype":"Chart","type":"Plot"}},"id":"c76f8f96-f7ec-471d-a8cd-33181acda024","type":"PanTool"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"Country":["Taiwan"],"Status":["R"],"chart_index":[{"Country":"Taiwan","Status":"R"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[1643.0],"label":[{"Country":"Taiwan","Status":"R"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["Taiwan:0.25"],"y":[821.5]}},"id":"536b0f98-24f9-40f0-9ff5-9390fb908b2f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b98db998-f25d-45bb-ace5-1f598ecc7570","type":"ColumnDataSource"},"glyph":{"id":"75cf9f53-4b68-4b65-bfed-c4d3f8759464","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c3b33914-2ee7-454b-b3cd-c2c4d6ed82a0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"aa3d323d-94ff-46a2-bcc6-df8cbafcfa15","subtype":"Chart","type":"Plot"}},"id":"9a0fa21b-23cf-468c-9a5d-bdc588f38d8c","type":"SaveTool"},{"attributes":{"data_source":{"id":"41b6e85f-c1f7-4964-978d-42055a829a26","type":"ColumnDataSource"},"glyph":{"id":"c38bf947-362d-4033-a061-18bb8eec587f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3211920c-74d7-4aa6-8cf7-8042efcf8367","type":"GlyphRenderer"},{"attributes":{"background_fill_color":{"value":"black"},"below":[{"id":"09d0cc2d-8973-4e40-be10-273c38b8370c","type":"CategoricalAxis"}],"height":300,"left":[{"id":"ce11b5ed-ea32-42cc-a797-0a56f0b70422","type":"LinearAxis"}],"outline_line_color":{"value":"gray"},"renderers":[{"id":"252dad7a-43d0-480d-85bd-f90947084a69","type":"BoxAnnotation"},{"id":"3c975b76-afd6-401b-940f-e90b5abe224c","type":"GlyphRenderer"},{"id":"e70c6624-45a6-4299-b7a9-897600facea6","type":"GlyphRenderer"},{"id":"f4e3ef3a-c4e6-4415-b8dd-57592b21ee98","type":"GlyphRenderer"},{"id":"da1ca9cf-7e9d-4871-a022-40a9e2b5e8fa","type":"GlyphRenderer"},{"id":"9e8e6eb5-2b7e-4425-b0a5-d96668cd1503","type":"GlyphRenderer"},{"id":"b3d41ccf-8101-4060-aed9-9313db2b6ea3","type":"GlyphRenderer"},{"id":"467e84ef-d2ce-4ffb-a5f9-5c4886e5e929","type":"GlyphRenderer"},{"id":"3211920c-74d7-4aa6-8cf7-8042efcf8367","type":"GlyphRenderer"},{"id":" ...

# %% [markdown]
# * Use **stack** instead of **group**

# %%
bar_stack = Bar(df, values='CustomerNumber', label='Country',agg='sum', stack='Status',
                xlabel='Country', ylabel="Total Customer",  
                title="Bar Chart", legend="top_right",
                outline_line_color="gray",background_fill_color="black",
                width=800, height=300)
show(bar_stack)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="01ff9e95-7f95-41ef-9683-8e58a471950b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#01ff9e95-7f95-41ef-9683-8e58a471950b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01ff9e95-7f95-41ef-9683-8e58a471950b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01ff9e95-7f95-41ef-9683-8e58a471950b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dda8570f-b355-4995-9a54-93052a75124b":{"roots":{"references":[{"attributes":{"callback":null,"factors":["Australia","Canada","England","Iceland","Japan","Korea","Taiwan","USA"]},"id":"030920f3-37c3-4ba1-bd3d-47385db07764","type":"FactorRange"},{"attributes":{},"id":"353a13f8-dddd-4971-904b-2379ccae0397","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f1ae40b6-83b5-4759-8f57-0c32f1ecea1c","type":"PanTool"},{"id":"86296eae-3688-4349-839e-ab6f9e14490a","type":"WheelZoomTool"},{"id":"77bdc10f-8558-45db-9aad-b674e6808cc4","type":"BoxZoomTool"},{"id":"508eb31a-db26-4090-9566-d6d707266833","type":"SaveTool"},{"id":"6e65259c-395d-4cbc-9dfc-410f045b455a","type":"ResetTool"},{"id":"ba459701-c822-41e6-be34-af18f755b643","type":"HelpTool"}]},"id":"e533b5c6-513b-4abb-a0d5-620be661a1c5","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"Country":["Canada"],"Status":["O"],"chart_index":[{"Country":"Canada","Status":"O"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[89.0],"label":[{"Country":"Canada","Status":"O"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Canada"],"y":[44.5]}},"id":"5e91f147-8676-4881-9f3a-fd9d773c1e1f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3e2d5b8a-49fa-40f2-993e-d215b736ec75","type":"ColumnDataSource"},"glyph":{"id":"f868cc2f-05ea-4cb8-a260-e264151b3e0f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b3d3f7fd-3617-432a-936e-1ab17a1605a9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"Country":["Australia"],"Status":["R"],"chart_index":[{"Country":"Australia","Status":"R"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[2090.0],"label":[{"Country":"Australia","Status":"R"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Australia"],"y":[1834.0]}},"id":"6c6efea4-c7ce-4008-b850-ea104b4cf078","type":"ColumnDataSource"},{"attributes":{},"id":"1433f3e5-af2b-4591-9023-4490f819926c","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"Country":["Korea"],"Status":["R"],"chart_index":[{"Country":"Korea","Status":"R"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[1344.0],"label":[{"Country":"Korea","Status":"R"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Korea"],"y":[672.0]}},"id":"14ed054a-0efb-4a30-83be-a0bce3aa9160","type":"ColumnDataSource"},{"attributes":{"axis_label":"Country","formatter":{"id":"f42dafec-d8af-4f2a-a6bb-7cb9a683849f","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"ef9dd1d4-43f8-4ea7-8849-c6f75a3f589c","subtype":"Chart","type":"Plot"},"ticker":{"id":"1433f3e5-af2b-4591-9023-4490f819926c","type":"CategoricalTicker"}},"id":"ab3517e7-21f7-4831-9d36-3d297e8ea375","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b34f7b59-2506-4620-8be9-9637fecb4626","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7afc4c7-7873-49bc-ab5d-5383690f15ad","type":"Rect"},{"attributes":{"plot":null,"text":"Bar Chart"},"id":"7dcf1f06-b8e3-4eab-be48-f6dd12055ddd","type":"Title"},{"attributes":{"data_source":{"id":"26435591-5518-480a-be0d-4dc37ba8ac33","type":"ColumnDataSource"},"glyph":{"id":"85f38e82-4fe2-49a0-8435-b5311 ...

# %% [markdown]
# # Box Plot
# * Separate different groups with **label**
# * Could set whisker color
# * Could ignore outlier (**outlier=False**)

# %%
from bokeh.charts import BoxPlot

# %%
box = BoxPlot(df, values='Stars', label='Status', color='Status', whisker_color='Status', outliers=True,
              xlabel='Status ', ylabel='Distribution of Stars', title='Box Plot', legend='bottom_left',
             width=400, height=250)
show(box)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="26b05f13-e252-404d-a47e-82326bfd1805"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#26b05f13-e252-404d-a47e-82326bfd1805").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("26b05f13-e252-404d-a47e-82326bfd1805");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '26b05f13-e252-404d-a47e-82326bfd1805' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"91790a7f-a0b3-4ce2-9438-96189743b91b":{"roots":{"references":[{"attributes":{"data_source":{"id":"acfb2317-48ce-4a71-9ffa-33208aa0db0f","type":"ColumnDataSource"},"glyph":{"id":"53941bd0-85eb-47f9-b2a6-a8b03ce8df0a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a8f630fa-e4b7-4189-820d-fd3d0f65dcc6","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8382612e-f1e1-41fb-9bab-bd46242b0a02","type":"PanTool"},{"id":"cc106b0f-2d15-48cc-900a-64d706440735","type":"WheelZoomTool"},{"id":"aedd17b6-28e9-4f92-a394-99cf092897b0","type":"BoxZoomTool"},{"id":"e29cd4a6-2514-481a-80ac-de74af7d0b94","type":"SaveTool"},{"id":"4ff302fb-9171-4e5a-ae5c-c9828ea822a5","type":"ResetTool"},{"id":"faf6c17c-3fc3-456a-95c3-7c96620a0065","type":"HelpTool"}]},"id":"772a7052-dfa6-4d4b-a134-4f56682ac262","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","label","y"],"data":{"Status":["R"],"chart_index":[{"Status":"R"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Status":"R"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["R"],"y":[5.5]}},"id":"7f8e8242-f1a5-4d6c-a349-7daf70e0e683","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1ec9da3a-0d40-47df-abb1-78de3f04cf4c","type":"ColumnDataSource"},"glyph":{"id":"7e81fde1-3c0b-41ef-bbe1-c0a11ec96f7f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4cc1d1f9-af92-4176-89e9-2062f2108030","type":"GlyphRenderer"},{"attributes":{},"id":"d4dd8be5-706f-4403-8f0a-5b4d9dd7557c","type":"CategoricalTickFormatter"},{"attributes":{},"id":"802df947-0939-488b-877d-4f9fc061e4b0","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x0s","y1s","x1s","y0s"],"data":{"Status":["O","O","O","O"],"chart_index":[{"Status":"O"},{"Status":"O"},{"Status":"O"},{"Status":"O"}],"x0s":["O:0.5","O:0.65","O:0.5","O:0.65"],"x1s":["O:0.5","O:0.35","O:0.5","O:0.35"],"y0s":[1.0,1.0,3.0,4.5],"y1s":[2.0,1.0,4.5,4.5]}},"id":"25cf66d3-433a-481b-9431-075aba9b3b69","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#407ee7"},"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"99a55222-7fb6-4d55-8a9a-6a537df24315","type":"Segment"},{"attributes":{"overlay":{"id":"771c8a0c-2e4a-4869-b46d-c967da0bcd6c","type":"BoxAnnotation"},"plot":{"id":"08f6b7b0-5087-4684-8180-3a36149bd2cd","subtype":"Chart","type":"Plot"}},"id":"aedd17b6-28e9-4f92-a394-99cf092897b0","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9e123213-1cc5-401c-b659-8c5143905995","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"1d8040ed-d025-40c0-ac2c-15b4d8c6dcc9","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"91d2c32a-03f3-475e-afcd-706e6c4b855a","type":"Circle"},{"attributes":{"callback":null,"column_names":["x0s","y1s","x1s","y0s"],"data":{"Status":["I","I","I","I"],"chart_index":[{"Status":"I"},{"Status":"I"},{"Status":"I"},{"Status":"I"}],"x0s":["I:0.5","I:0.65","I:0.5","I:0.65"],"x1s":["I:0.5","I:0.35","I:0.5","I:0.35"],"y0s":[5.5,5.5,8.0,9.0],"y1s":[7.0,5.5,9.0,9.0]}},"id":"16721ea1-0c04-4a2e-8ad7-1882e199d93c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","width","height","color","x","fill_alpha","line_color","labe ...

# %% [markdown]
# # Add Annotations on Your Plot
# * Customize your tools bar
#     * **pan**/**reset**/**save**/**crosshair**/**wheel_zoom**/**box_zoom**/**box_select**/**lasso_select**
#         * (e.g. : plot = figure(tools="pan,wheel_zoom,box_zoom,reset"))
#         * (e.g. : plot = figure(tools="", logo=None))
#     * **HoverTool**
# * Figure.XXXX() :
#     * **Circle**/**Line**/**Diamond**/** Square**/**Oval**
# * add_layout() :
#     * **Text**/**Arrow**

# %%
from bokeh.plotting import figure
from bokeh.models import HoverTool,Label, Arrow, VeeHead, OpenHead

# %%
hover = HoverTool(tooltips=[("(x,y)", "($x, $y)")])

# %%
Face = figure(width=400, height=240, tools=["hover,lasso_select"])
Face.circle([5] ,[-60], color='brown', size=200, radius=5, alpha=0.6, line_color='black')
Face.line(x=[1, 2, 3, 4, 5, 6, 7, 8, 9 ], y=[200, 350, 470, 530, 560,530, 470, 350, 200], color='black')
Face.circle([5], color='red',size=60)
Face.circle([3.5, 6.5], [200, 200], color='Black',size=40)
Face.diamond([3.5, 6.5], [200, 200], color='gray',size=30, alpha=0.5)
Face.square([3.57, 6.57], [208, 208], color='white',size=3, alpha=1)
Face.oval([3, 7], [105, 105], fill_color='pink', line_color=None, height=50, width=2)

myText = Label(x=8.5, y=-60, text='Here')
Face.add_layout(myText)

myArrow_OH = Arrow(end=OpenHead(size=15, line_color="red", line_width=4),
                line_color="red", x_start=7.5, y_start=60, x_end=8.5, y_end=0)
Face.add_layout(myArrow_OH)

myArrow_VH = Arrow(end=VeeHead(size=15, fill_color="black", line_width=2),
                line_color="black", x_start=1.5, y_start=600, x_end=2.3, y_end=510)
Face.add_layout(myArrow_VH)

show(Face)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d1e16270-6575-4b11-bba7-019e6beeefcc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#d1e16270-6575-4b11-bba7-019e6beeefcc").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d1e16270-6575-4b11-bba7-019e6beeefcc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd1e16270-6575-4b11-bba7-019e6beeefcc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"da7ea397-335e-4b7d-a301-c92b47ecc95d":{"roots":{"references":[{"attributes":{"callback":null},"id":"7344c0ec-3723-4871-bb51-67ff655bc403","type":"DataRange1d"},{"attributes":{"plot":{"id":"875a1391-565c-4cab-a905-8051b4321989","subtype":"Figure","type":"Plot"},"text":"Here","x":8.5,"y":-60},"id":"34f66ebe-7e50-4c23-8b93-6c390888f35d","type":"Label"},{"attributes":{"line_width":{"value":2},"plot":null,"size":15},"id":"3e2575e0-5759-47b6-896d-c3ddadb44656","type":"VeeHead"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"e30b4d31-424e-4685-9c63-6b2c1969b564","type":"Diamond"},{"attributes":{},"id":"6b969f9d-b81b-4b86-9376-58974e94aefe","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.5,6.5],"y":[200,200]}},"id":"5219b1f9-b97b-42d5-990c-ea92199571cd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"line_alpha":{"value":0.5},"line_color":{"value":"gray"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad277c6d-4d87-4190-a45b-65be001cd260","type":"Diamond"},{"attributes":{"formatter":{"id":"1b7d45b3-996e-4de8-8cb8-1478a65c038b","type":"BasicTickFormatter"},"plot":{"id":"875a1391-565c-4cab-a905-8051b4321989","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1fca438-0abf-41a4-9399-28e790865e5d","type":"BasicTicker"}},"id":"e7c01a3a-b5e5-4c31-95a8-e2638f8b4300","type":"LinearAxis"},{"attributes":{"data_source":{"id":"838c2eaf-f545-47fe-b541-b2d99770ab40","type":"ColumnDataSource"},"glyph":{"id":"e2471605-de64-4562-ba9f-3ca275f6577c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"bac4ee7e-81d4-43eb-b96b-9da1da7c5aaa","type":"Circle"},"selection_glyph":null},"id":"cbea7a96-0f1d-43b5-b23c-05095491b63f","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"efc201e4-c051-45d1-80f6-824823d09d61","type":"Line"},{"attributes":{"callback":null,"column_names":["x"],"data":{"x":[5]}},"id":"838c2eaf-f545-47fe-b541-b2d99770ab40","type":"ColumnDataSource"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"f693d97d-5281-4571-abe0-4e0b78f0aeed","type":"Line"},{"attributes":{"fill_color":{"value":"pink"},"height":{"units":"data","value":50},"line_color":{"value":null},"width":{"units":"data","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"41c717e4-e9d5-4fcd-837f-07cf0711ccf0","type":"Oval"},{"attributes":{},"id":"b1fca438-0abf-41a4-9399-28e790865e5d","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":60},"x":{"field":"x"}},"id":"bac4ee7e-81d4-43eb-b96b-9da1da7c5aaa","type":"Circle"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":4},"plot":null,"size":15},"id":"ceace9c4-963b-4957-85e6-506bb0d3f37a","type":"OpenHead"},{"attributes":{"below":[{"id":"427ee23d-4f12-4693-b1fc-8047aa0cd3bc","type":"LinearAxis"}],"left":[{"id":"e7c01a3a-b5e5-4c31-95a8-e2638f8b4300","type":"LinearAxis"}],"plot_height":240,"plot_width":400,"renderers":[{"id":"427ee23d-4f12-4693-b1fc-8047aa0cd3bc","type":"LinearAxis"},{"id":"49a8b8a6-e318-4704-9bb6-d4efb2e0ef1c","type":"Grid"},{"id":"e7c01a3a-b5e5-4c31-95a8-e2638f8b4300","type":"LinearAxis"},{"id":"ed3c5630-2067-4da4-bad0-2c7176045afc","type":"Grid"},{"id":"0cff986e-a628-4c14-b08a-abcbad1116cd","type":"PolyAnnotation"},{"id":"b5ea6a10-8363-4af9-9fc6-f3b827c9368f","type":"GlyphRenderer"},{"id":"f1a214cc-a337-41ec-8f94-48040e245f62","type":"GlyphRenderer"},{"id":"cbea7a96-0f1d-43b5-b23c-05095491b63f","type":"GlyphRenderer"},{"id":"b2942680-c0b6-4bc0-94ed-9d8dcccecc94","type":"GlyphRenderer"},{"id":"9ec34bab-519c-4dc1-ab66-0784ada2437b","type":"GlyphRenderer"},{"id":"3da ...

# %% [markdown]
# # Embed Plots in HTML

# %%
from bokeh.plotting import figure
from bokeh.resources import CDN
from bokeh.embed import components

# %% [markdown]
# * Get **js file** & **css file** informations, fill this in HTML **head part**

# %%
print(CDN.js_files)
print(CDN.css_files)
# Out:
# ['https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.3.min.js']
# ['https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.css', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.3.min.css']

# %% [markdown]
# * Create a plot and get **div** & **script** , fill this in HTML **body part**

# %%
# script, div = components(hist, CDN)
# print(script)
# print(div)

# plots can be a single Bokeh Model, a list/tuple, or even a dictionary
plots = {'Histogram Plot': hist, 'Scatter Plot': scatter, 'Bar Plot': bar,
         'Bar Plot(Stack)': bar_stack, 'Box Plot': box, 'Face': Face}

script, div = components(plots)

with open('Bokeh_Script.html', 'w') as html_file:
    print("<!DOCTYPE HTML>", "\n",
          "<html>", "\n",
          "<head>", "\n",
          "<h> Create by Bokeh</h>", "\n",
          "<link href='{}' rel='stylesheet' type='text/css'></link>".format(CDN.css_files[0]), "\n",
          "<link href='{}' rel='stylesheet' type='text/css'></link>".format(CDN.css_files[1]), "\n",
          "<script src='{}'></script>".format(CDN.js_files[0]), "\n",
          "<script src='{}'></script>".format(CDN.js_files[1]), "\n",
          "</head>", "\n",
          "\n"
          "<body>", "\n",
          "{}, {}, {}, {}, {}, {}".format(div['Histogram Plot'],
                                          div['Scatter Plot'],
                                          div['Bar Plot'],
                                          div['Bar Plot(Stack)'],
                                          div['Box Plot'],
                                          div['Face']) , "\n", "\n"
          "<!-- Java Script for Plot-->",
          script, "\n",
          "</body>", "\n",
          "</html>",          
          file=html_file)

# %% [markdown]
# # Interactive in Notebook

# %% [markdown]
# * Widgets
#     * Slider
#     * RadioButtonGroup
#     * Select
#     * Button

# %%
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Button, RadioButtonGroup, Select, Slider

# %%
# Create widgets
slider = Slider(start=0, end=10, value=1, step=.1, title="Slider")
button_group = RadioButtonGroup(labels=["Olly", "Oil", "Ollier"], active=0)
select = Select(title="Who are you:", value="Olly", options=['Olly', 'Oil', 'Ollier', 'Olliver'])
button = Button(label="Hit Me~")

# Put the results in a row
show(widgetbox(button, slider, button_group, select, width=300))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="429e1e40-48f5-43a1-9499-64b8d4482739"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#429e1e40-48f5-43a1-9499-64b8d4482739").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("429e1e40-48f5-43a1-9499-64b8d4482739");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '429e1e40-48f5-43a1-9499-64b8d4482739' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"98fdf684-b87a-4ee8-8521-80558c3d4bc8":{"roots":{"references":[{"attributes":{"callback":null,"end":10,"title":"Slider","value":1},"id":"85873a1c-1527-4626-b466-f1b76b19d2b9","type":"Slider"},{"attributes":{"callback":null,"icon":null,"label":"Hit Me~"},"id":"a9a4beb6-506f-42e3-904e-bf0e88c43cb4","type":"Button"},{"attributes":{"callback":null,"options":["Olly","Oil","Ollier","Olliver"],"title":"Who are you:","value":"Olly"},"id":"46072e89-34e7-4759-a532-cbd77e8b46e0","type":"Select"},{"attributes":{"active":0,"callback":null,"labels":["Olly","Oil","Ollier"]},"id":"347b860a-e950-4cb2-ae6d-b63c53c1689e","type":"RadioButtonGroup"},{"attributes":{"children":[{"id":"a9a4beb6-506f-42e3-904e-bf0e88c43cb4","type":"Button"},{"id":"85873a1c-1527-4626-b466-f1b76b19d2b9","type":"Slider"},{"id":"347b860a-e950-4cb2-ae6d-b63c53c1689e","type":"RadioButtonGroup"},{"id":"46072e89-34e7-4759-a532-cbd77e8b46e0","type":"Select"}],"width":300},"id":"b619722e-94d7-442f-a7ad-87e78060f323","type":"WidgetBox"}],"root_ids":["b619722e-94d7-442f-a7ad-87e78060f323"]},"title":"Bokeh Application","version":"0.12.3"}};
#             var render_items = [{"docid":"98fdf684-b87a-4ee8-8521-80558c3d4bc8","elementid":"429e1e40-48f5-43a1-9499-64b8d4482739","modelid":"b619722e-94d7-442f-a7ad-87e78060f323"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === "1")) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === "1") {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (!force) {
#         var cell = $("#429e1e40-48f5-43a1-9499-64b8d4482739").parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9caeee88-ba2d-4dea-8618-185a5ef59152">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

# %%
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e589d302-3051-48e9-8242-b723c7fee3e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e589d302-3051-48e9-8242-b723c7fee3e7").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("9c39807d-858d-456b-8ecd-520c29f44a0c", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e589d302-3051-48e9-8242-b723c7fee3e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e589d302-3051-48e9-8242-b723c7fee3e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a3e8e32f-29e7-43e5-b532-f3cd95d7e1cd":{"roots":{"references":[{"attributes":{"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"}},"id":"62f8a143-a08c-42b9-af84-9e2f9d637ef8","type":"ResetTool"},{"attributes":{"plot":null,"text":"simple line example"},"id":"71eedc0c-6d19-4457-8463-74a0d8055cc8","type":"Title"},{"attributes":{"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"}},"id":"127a2d04-9d33-4350-a5b1-1be39d8e2a7b","type":"SaveTool"},{"attributes":{"data_source":{"id":"371ac55a-1f86-45c2-9b4f-63a39d9a4f2d","type":"ColumnDataSource"},"glyph":{"id":"825563d9-9af6-4afe-99e4-f3ce3f0d4eb9","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5b5298cc-a355-4b4b-9cd2-649c7f3a168a","type":"Line"},"selection_glyph":null},"id":"44ac0b4f-d4e0-43cd-967a-232f80af739f","type":"GlyphRenderer"},{"attributes":{},"id":"5f6cff2a-f3cb-48c3-bfe4-40007f750ecc","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b5298cc-a355-4b4b-9cd2-649c7f3a168a","type":"Line"},{"attributes":{"callback":null,"end":5,"start":-5},"id":"d8667289-1b09-43c3-80e0-8de6a7f608c8","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f352c03e-a741-42ba-867b-483eefd537b8","type":"PanTool"},{"id":"2e9c5cd1-4b1c-46e8-9711-b7884f66cdb3","type":"WheelZoomTool"},{"id":"6ab77e5a-8d24-4f66-ad13-7b78c6568254","type":"BoxZoomTool"},{"id":"127a2d04-9d33-4350-a5b1-1be39d8e2a7b","type":"SaveTool"},{"id":"62f8a143-a08c-42b9-af84-9e2f9d637ef8","type":"ResetTool"},{"id":"eb0cff14-47ef-4477-82ab-96c5ff00f264","type":"HelpTool"}]},"id":"d5e47ea5-5f5d-4442-aca2-678b50e4e0e5","type":"Toolbar"},{"attributes":{"overlay":{"id":"c161d149-fd16-4cb8-8678-ebfc03254d78","type":"BoxAnnotation"},"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"}},"id":"6ab77e5a-8d24-4f66-ad13-7b78c6568254","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"9bb62b11-6d13-4ba5-8b93-5da9ae89f286","type":"BasicTickFormatter"},"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c388024-e033-417b-b179-454891e02900","type":"BasicTicker"}},"id":"42f5d77e-64b7-4a76-a2a3-730b8039b31d","type":"LinearAxis"},{"attributes":{"formatter":{"id":"67b83a9c-abc2-4f58-b7f9-a1e17c297e31","type":"BasicTickFormatter"},"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"},"ticker":{"id":"2ed0bf20-c180-4c8a-8f9c-80f0f115d2e8","type":"BasicTicker"}},"id":"95bed250-748d-444f-a5b5-f6c64f841c66","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c161d149-fd16-4cb8-8678-ebfc03254d78","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"}},"id":"f352c03e-a741-42ba-867b-483eefd537b8","type":"PanTool"},{"attributes":{},"id":"7c388024-e033-417b-b179-454891e02900","type":"BasicTicker"},{"attributes":{"callback":null},"id":"21090d95-c201-4544-90b9-7c9a835d0469","type":"DataRange1d"},{"attributes":{},"id":"9bb62b11-6d13-4ba5-8b93-5da9ae89f286","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"825563d9-9af6-4afe-99e4-f3ce3f0d4eb9","type":"Line"},{"attributes":{},"id":"67b83a9c-abc2-4f58-b7f9-a1e17c297e31","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"7a975de5-4281-4e75-ada8-aef53b277ca6","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c388024-e033-417b-b179-454891e02900","type":"BasicTicker"}}, ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[25]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,5), phi=(0, 20, 0.1))
# Out:
# <function __main__.update>
