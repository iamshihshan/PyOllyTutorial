# %% [markdown]
# # Bokeh
# * Let's create interactive html graph wiht bokeh
# * [More examples](http://bokeh.pydata.org/en/latest/docs/gallery.html#gallery)
# * [More Tutorial 1](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/tree/master/tutorial/)
# * [More Tutorial 2](http://bokeh.pydata.org/en/latest/docs/user_guide.html)

# %%
from bokeh.io import output_notebook, show
output_notebook()
import pandas as pd
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="397c01b7-8a78-4e94-9b16-5c41bc02a9c7">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('DataBase/CSVData.csv')
df.head()
# Out:
#    ID           Date Country  Star  Total Customer Status Target
# 0   1  6/9/2017 0:00     USA     6       5244337.0      O      Y
# 1   2  6/9/2017 0:00  Canada     5       3531127.0      R      Y
# 2   3  6/9/2017 0:00  French     5        253535.0      I      N
# 3   4  6/9/2017 0:00  Taiwan     4       5165465.0    NaN      N
# 4   5  6/9/2017 0:00   Japan     6             NaN    NaN      Y

# %% [markdown]
# # Change Defaults Width & Height

# %%
from bokeh.charts import defaults

defaults.width = 600
defaults.height = 300
# Out:
# /usr/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)

# %% [markdown]
# # Histogram plot
# * Separate different group with **color**
# * Set **bins** for customize distance of frequency

# %%
from bokeh.charts import Histogram

# %%
hist = Histogram(df, values='Star', color='Status', bins=3,
                 xlabel='Distribution of Stars', ylabel='Frequency of Stars',
                 title='Histogram Plot', legend='top_left')
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f06a9833-da4e-43c5-b1ed-30415a76dc31"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f06a9833-da4e-43c5-b1ed-30415a76dc31");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f06a9833-da4e-43c5-b1ed-30415a76dc31");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f06a9833-da4e-43c5-b1ed-30415a76dc31' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f409744c-e670-47f7-8f50-a4495ffdd37e":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"835ae415-6884-446e-a4bc-8b090842443c","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(4.666667, 5.333333]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[1.0],"label":["(4.666667, 5.333333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.6666666666666661],"x":["5.0"],"y":[0.5]}},"id":"0c96c715-a9fe-4147-ae92-eedf44b9f1d8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"03cea148-4b75-47c0-9f0e-8d77ee641572","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["[4.000000, 4.666667]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[1.0],"label":["[4.000000, 4.666667]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.666666666666667],"x":["4.3333335"],"y":[0.5]}},"id":"973bafdb-074b-41f3-87d2-e8a4b5f236a4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1145f443-99fb-45a3-98c7-56792f2e252e","type":"ColumnDataSource"},"glyph":{"id":"835ae415-6884-446e-a4bc-8b090842443c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a7ce2bd5-6444-477a-9deb-2b0a332e35e5","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0c96c715-a9fe-4147-ae92-eedf44b9f1d8","type":"ColumnDataSource"},"glyph":{"id":"fc99ae77-2713-4e78-92ea-5d450324c0ea","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ae0b45ee-0b4e-4b95-8724-1836bc2b5d9b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"62ece268-d906-41b7-a147-ff0bcb1f9f10","type":"Rect"},{"attributes":{"label":{"value":"R"},"renderers":[{"id":"96ec74f5-01e2-452f-abca-bf666c20556a","type":"GlyphRenderer"},{"id":"5ae0369b-8cf6-4c7c-ac6e-cfebaae8f29e","type":"GlyphRenderer"},{"id":"261ba1d2-ecbc-43f4-b681-173d00882c46","type":"GlyphRenderer"}]},"id":"c9bcd2d3-dd97-4984-83b5-36cc53b1a5bc","type":"LegendItem"},{"attributes":{},"id":"95b29488-8c00-48fe-bf7e-24905bb31cc4","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7fb7c6ea-9eac-4044-a832-abbc125cc8eb","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a7041581-f7c0-460d-8723-18d81b08a15c","type":"Rect"},{"attributes":{"data_source":{"id":"017e0cee-f5b8-48b0-b0cf-f4803e39869d","type":"ColumnDataSource"},"glyph":{"id":"4c634800-f500-4595-8f1d-4f47b049b04f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1197e678-f5be-49d1-88dc-b22a92d8ed58","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field": ...

# %% [markdown]
# # Scatter Plot
# * Separate different groups with **marker** & **color**

# %%
from bokeh.charts import Scatter

# %%
scatter = Scatter(df, x='Star', y='Total Customer', marker='Country', color='Country',
                  xlabel="Star", ylabel="Total Customer",
                  title="Scatter Plot", legend="top_left",
                  outline_line_color="gray",background_fill_color="pink",
                  width=700, height=300)
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6552eb2f-ada0-4c96-9f85-b3d3b370b727"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6552eb2f-ada0-4c96-9f85-b3d3b370b727");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6552eb2f-ada0-4c96-9f85-b3d3b370b727");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6552eb2f-ada0-4c96-9f85-b3d3b370b727' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b4c8f266-5732-401f-9ade-1ed162c66fa6":{"roots":{"references":[{"attributes":{"label":{"value":"Japan"},"renderers":[{"id":"b6ca8dbc-dfd0-46ee-abf8-88e9d27f88a6","type":"GlyphRenderer"}]},"id":"f1c503d8-1cd2-477c-a50d-0ccf89cd1cac","type":"LegendItem"},{"attributes":{"items":[{"id":"3712f6cc-ba86-43c9-814c-3b3929688032","type":"LegendItem"},{"id":"55116215-a995-4ce1-9b49-f0e89a700b8f","type":"LegendItem"},{"id":"a519cf79-1b9c-44a4-8ae6-3630a4c5d7ea","type":"LegendItem"},{"id":"01ec9931-8163-44bb-baaf-db001b023b65","type":"LegendItem"},{"id":"f1c503d8-1cd2-477c-a50d-0ccf89cd1cac","type":"LegendItem"},{"id":"32ea31c2-c3f7-4fc3-910f-a8bd11e3f71f","type":"LegendItem"},{"id":"450b5229-ad24-4395-a14b-fac08ce5f19b","type":"LegendItem"}],"location":"top_left","plot":{"id":"b37d79bf-ea50-48cb-bf58-b07c58563f29","subtype":"Chart","type":"Plot"}},"id":"5afe86e6-5f76-4f6f-babb-65f15f35b1b9","type":"Legend"},{"attributes":{"label":{"value":"Korea"},"renderers":[{"id":"5831e18c-7ae8-48c3-b877-c5de062061ed","type":"GlyphRenderer"}]},"id":"32ea31c2-c3f7-4fc3-910f-a8bd11e3f71f","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"9d679ee7-f31e-4781-975c-89820da4985b","type":"Diamond"},{"attributes":{"label":{"value":"England"},"renderers":[{"id":"a313856b-f3c7-4c23-b00f-9d04dabde43a","type":"GlyphRenderer"}]},"id":"450b5229-ad24-4395-a14b-fac08ce5f19b","type":"LegendItem"},{"attributes":{"plot":{"id":"b37d79bf-ea50-48cb-bf58-b07c58563f29","subtype":"Chart","type":"Plot"}},"id":"9cf070d6-da0d-4019-8385-46d4ea82ed4b","type":"SaveTool"},{"attributes":{"callback":null,"end":7.3,"start":3.7},"id":"fcf5ee01-5cba-4d9b-abbf-dffac23fcb0b","type":"Range1d"},{"attributes":{"data_source":{"id":"4d973cdf-79f8-4e77-8e9c-a4eb3d174a8f","type":"ColumnDataSource"},"glyph":{"id":"b309e28b-5688-4a1b-a91b-af503bc3d3f7","type":"Asterisk"},"hover_glyph":null,"muted_glyph":null},"id":"592ed5ed-0106-4356-8b15-e0f8966f2d4e","type":"GlyphRenderer"},{"attributes":{"label":{"value":"USA"},"renderers":[{"id":"743d99b2-7ab2-4f89-8381-17fecbf966e0","type":"GlyphRenderer"}]},"id":"3712f6cc-ba86-43c9-814c-3b3929688032","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Country":["Japan","Japan"],"chart_index":[{"Country":"Japan"},{"Country":"Japan"}],"x_values":[6,6],"y_values":{"__ndarray__":"AAAAAAAA+H8AAAAAAErTQA==","dtype":"float64","shape":[2]}}},"id":"3b92ef36-f23e-4e0c-8d23-46f2bf7ab357","type":"ColumnDataSource"},{"attributes":{"background_fill_color":{"value":"pink"},"below":[{"id":"312610cd-38a6-440f-8505-f7b551b791f0","type":"LinearAxis"}],"css_classes":null,"height":300,"left":[{"id":"9a42813c-3317-4ed6-8f63-dc9795c93ebb","type":"LinearAxis"}],"outline_line_color":{"value":"gray"},"renderers":[{"id":"b3d95169-19b6-4ea4-90db-5b5c6ed8cd7e","type":"BoxAnnotation"},{"id":"743d99b2-7ab2-4f89-8381-17fecbf966e0","type":"GlyphRenderer"},{"id":"5550eb44-68f6-47f1-a9f4-4e851294cf46","type":"GlyphRenderer"},{"id":"e7c02b30-ca4d-44e8-a545-4429bb9d6521","type":"GlyphRenderer"},{"id":"592ed5ed-0106-4356-8b15-e0f8966f2d4e","type":"GlyphRenderer"},{"id":"b6ca8dbc-dfd0-46ee-abf8-88e9d27f88a6","type":"GlyphRenderer"},{"id":"5831e18c-7ae8-48c3-b877-c5de062061ed","type":"GlyphRenderer"},{"id":"a313856b-f3c7-4c23-b00f-9d04dabde43a","type":"GlyphRenderer"},{"id":"5afe86e6-5f76-4f6f-babb-65f15f35b1b9","type":"Legend"},{"id":"312610cd-38a6-440f-8505-f7b551b791f0","type":"LinearAxis"},{"id":"9a42813c-3317-4ed6-8f63-dc9795c93ebb","type":"LinearAxis"},{"id":"ebd2402d-a384-4b52-918f-b4f674a11772","type":"Grid"},{"id":"06d3a894-4a8d-4237-a6a2-f3c7a7b8dcca","type":"Grid"}],"title":{"id":"77f90e50-adec-4d93-959b-c14bdb0bf170","type":"Title"},"tool_events":{"id":"bd988963-a100-4079-9255-3bd9200dfca5","type":"ToolEvents"},"toolbar":{"id":"b18fdeeb-0f8f-41 ...

# %% [markdown]
# # Bar Plot
# * Separate differnt group with **label** & **group** (**color**)
# * Aggregate what you need with **agg**

# %%
from bokeh.charts import Bar

# %%
bar = Bar(df, values='Total Customer', label='Country', agg='sum', group='Status', color='Status',
          xlabel='Country', ylabel="Mean of CustomerNumber",
          title="Bar Chart", legend="top_right",
          outline_line_color="gray",background_fill_color="black",
          width=800, height=300)
show(bar)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2574cec7-ee17-4e16-91c1-dc2d2002ea18"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2574cec7-ee17-4e16-91c1-dc2d2002ea18");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2574cec7-ee17-4e16-91c1-dc2d2002ea18");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2574cec7-ee17-4e16-91c1-dc2d2002ea18' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"72bd5608-7e04-4444-b162-b207cd4ef953":{"roots":{"references":[{"attributes":{"data_source":{"id":"67a15dfe-ff3c-4f77-abe6-d554eaf784f1","type":"ColumnDataSource"},"glyph":{"id":"09c209c0-d102-4802-9fbd-dde7a2d6628e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ec7c2cea-4ea9-4e1b-a744-9406156c7c9c","type":"GlyphRenderer"},{"attributes":{"axis_label":"Country","formatter":{"id":"c861d9fd-404a-4704-9065-10a14d8bc912","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"57670d02-4b09-4be2-8582-1fcc1bd34526","subtype":"Chart","type":"Plot"},"ticker":{"id":"7e8abc71-2cf9-437e-9d8f-02b6064f9f38","type":"CategoricalTicker"}},"id":"8618581a-2216-4103-b0ae-6f63e85d80c9","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"16c5a593-ce79-4b82-adfc-4d5462145b82","type":"ColumnDataSource"},"glyph":{"id":"37c37aff-c9f9-4501-9514-80ad97b1fe4b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"2436375a-1768-4062-92a6-5cb450bfc62e","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":11651292.45},"id":"bd1de6bd-aacd-476a-b87c-e306824f750e","type":"Range1d"},{"attributes":{"data_source":{"id":"ae59cee3-d6df-42db-b704-42d616277ac3","type":"ColumnDataSource"},"glyph":{"id":"e12abaa2-3916-48c0-9fb0-dc9892935aea","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"bb41a885-6a9e-459a-912f-7644dfff1d0b","type":"GlyphRenderer"},{"attributes":{},"id":"00079c38-12dc-4b49-90fb-4ee5850b980c","type":"CategoricalScale"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"24e81513-6175-42e6-b1a3-39bc731a6c3d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"37c37aff-c9f9-4501-9514-80ad97b1fe4b","type":"Rect"},{"attributes":{"plot":{"id":"57670d02-4b09-4be2-8582-1fcc1bd34526","subtype":"Chart","type":"Plot"}},"id":"2aca2a1f-cfd8-4972-8da1-daa2a9620483","type":"HelpTool"},{"attributes":{},"id":"a45bd0e5-3210-4d6e-b907-0788a620528b","type":"ToolEvents"},{"attributes":{"overlay":{"id":"8c46e70d-5294-46ca-a803-63e2b2a7cb27","type":"BoxAnnotation"},"plot":{"id":"57670d02-4b09-4be2-8582-1fcc1bd34526","subtype":"Chart","type":"Plot"}},"id":"700ccbdc-ead8-4a42-a1e2-85c5c8b514bd","type":"BoxZoomTool"},{"attributes":{"label":{"value":"O"},"renderers":[{"id":"bb41a885-6a9e-459a-912f-7644dfff1d0b","type":"GlyphRenderer"}]},"id":"37b17b71-e2a3-45de-ab6f-79ec1aa42f41","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1f86fd96-7134-44f6-a96b-b47b38cb7c43","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e5aaf215-271b-47c8-9f1f-6a42f677a99c","type":"Rect"},{"attributes":{},"id":"4bdfe938-50a7-462f-9e54-8177735b4bac","type":"LinearScale"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2bd4fe9-4002-44d0-a46d-b325fdb1cd4f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":" ...

# %% [markdown]
# * Use **stack** instead of **group**

# %%
bar_stack = Bar(df, values='Total Customer', label='Country',agg='sum', stack='Status',
                xlabel='Country', ylabel="Total Customer",  
                title="Bar Chart", legend="top_right",
                outline_line_color="gray",background_fill_color="black",
                width=800, height=300)
show(bar_stack)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9ef2ba0f-1917-495b-89ec-869bc4dfc0de"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9ef2ba0f-1917-495b-89ec-869bc4dfc0de");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ef2ba0f-1917-495b-89ec-869bc4dfc0de");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ef2ba0f-1917-495b-89ec-869bc4dfc0de' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"85d4432d-b84b-42a9-b474-8343c7956f0d":{"roots":{"references":[{"attributes":{"plot":{"id":"fc54af33-1706-4bc6-a32d-1bb2a8a4e369","subtype":"Chart","type":"Plot"}},"id":"7981eca9-273f-4442-999c-15dc47f6b45d","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f92f58bd-14c4-4485-8533-fd4f2789b870","type":"PanTool"},{"id":"7981eca9-273f-4442-999c-15dc47f6b45d","type":"WheelZoomTool"},{"id":"fabb71cd-3f11-4e87-bb64-fcb317d8ea62","type":"BoxZoomTool"},{"id":"e96b7202-c5ce-4b7e-9b75-29561392f6eb","type":"SaveTool"},{"id":"5b960286-4abb-46fd-b151-c8fc263959f6","type":"ResetTool"},{"id":"6f97865c-4bb8-4605-8977-da6428a294c6","type":"HelpTool"}]},"id":"faa1188b-0a75-444b-ad36-f69667146e33","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2e6768d7-e36d-4c32-9028-98680a35e174","type":"Rect"},{"attributes":{"data_source":{"id":"6684fcfa-b77e-4e59-a9be-8ed93c6f4011","type":"ColumnDataSource"},"glyph":{"id":"8e157030-7eaf-450e-9b98-f77efd67ac3f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"df44389c-08f7-4558-9d9f-70c55e7a1874","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Q"},"renderers":[{"id":"df44389c-08f7-4558-9d9f-70c55e7a1874","type":"GlyphRenderer"}]},"id":"db7fc42c-8115-42e5-8fb7-d1abb63a3344","type":"LegendItem"},{"attributes":{"data_source":{"id":"e1156aa9-dc2c-4fba-9284-f752454a03c5","type":"ColumnDataSource"},"glyph":{"id":"b8022dee-c941-47c7-8473-b782e8516477","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ee3d31f0-6810-4661-874f-d67ba60ad76a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Country":["England"],"Status":["R"],"chart_index":[{"Country":"England","Status":"R"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[4852122.0],"label":[{"Country":"England","Status":"R"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["England"],"y":[6887502.0]}},"id":"3724083c-0797-4696-b68f-fb4329ede660","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1d632e33-3176-4d61-8685-1e46439729fd","type":"ColumnDataSource"},"glyph":{"id":"2dddfec9-bf37-4364-8c45-08baa9006ee5","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d346c115-d02b-4db1-96c2-7ab9c3ae14da","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f484b904-9437-4230-824a-948dc4539f7a","type":"Rect"},{"attributes":{"data_source":{"id":"5860aec2-f66e-4b07-af48-877c71920718","type":"ColumnDataSource"},"glyph":{"id":"7d783d9a-2d9c-464a-a331-eb52360b8dec","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"502350d8-1916-4a36-9681-053d785b9121","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Country":["Canada"],"Status":["R"],"chart_index":[{"Country":"Canada","Status":"R"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[7367651.0],"label":[{"Country":"Canada","Status":"R"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Canada"],"y":[3683825.5]}},"id":"1d632e33-3176-4d61-8685-1e46439729fd","type":"ColumnDataSource"},{"attributes":{},"id":"e0806cc3-4e32-4271-a1d4-5312fdb56ba2","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Country":["Korea"],"Status":["R"],"chart_index":[{"Country":"Korea","Status":"R"}], ...

# %% [markdown]
# # Box Plot
# * Separate different groups with **label**
# * Could set whisker color
# * Could ignore outlier (**outlier=False**)

# %%
from bokeh.charts import BoxPlot

# %%
box = BoxPlot(df, values='Star', label='Status', color='Status', whisker_color='Status', outliers=True,
              xlabel='Status ', ylabel='Distribution of Stars', title='Box Plot', legend='bottom_right',
             width=800, height=250)
show(box)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a6810f5d-98f7-4494-971e-6502e216b1b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a6810f5d-98f7-4494-971e-6502e216b1b0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a6810f5d-98f7-4494-971e-6502e216b1b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a6810f5d-98f7-4494-971e-6502e216b1b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"34d07d07-67a9-4c45-bd32-27c8d2de38ae":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e426cf02-3e4d-4aa2-a750-dcd6b024a782","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Status":["R"],"chart_index":[{"Status":"R"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[0.25],"label":[{"Status":"R"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["R"],"y":[5.125]}},"id":"f77fb2e8-88a5-4801-a50e-2ca1bcbdc994","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"213de55c-9a45-46a6-be34-ae7a99fdaf83","type":"ColumnDataSource"},"glyph":{"id":"4129871d-68ce-4883-8496-dec3cde09c5e","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"1c9b7b6b-86e9-458e-a8d1-4e8e13a21c8a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"Status":["I","I","I","I"],"chart_index":[{"Status":"I"},{"Status":"I"},{"Status":"I"},{"Status":"I"}],"x0s":["I:0.5","I:0.65","I:0.5","I:0.65"],"x1s":["I:0.5","I:0.35","I:0.5","I:0.35"],"y0s":[4,4,7.0,7],"y1s":[4.75,4,7,7]}},"id":"207eb213-0ca7-47f9-92f3-ca17f4352657","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Status":["Q"],"chart_index":[{"Status":"Q"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Status":"Q"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Q"],"y":[6.0]}},"id":"80319f3d-b19d-492f-a694-a3aaac56476f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4c10ed96-09f0-41fd-a65c-a6835952adba","type":"ColumnDataSource"},"glyph":{"id":"e8124775-47b2-4ac2-944b-74e124056763","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f9ad33ee-ebf2-4149-a148-ee46ec158b38","type":"GlyphRenderer"},{"attributes":{"axis_label":"Status ","formatter":{"id":"96adcab0-7060-4813-9dcf-034560269fda","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"35181fec-e86f-464f-97fa-5e0215c28689","subtype":"Chart","type":"Plot"},"ticker":{"id":"59f3d932-e781-4c40-adcb-2de8df1bfea9","type":"CategoricalTicker"}},"id":"66545fcd-65f3-4d6e-b5bb-bc136e4d2e4a","type":"CategoricalAxis"},{"attributes":{},"id":"a9857b76-9c8f-4cde-b628-be41af08f12f","type":"CategoricalScale"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Status":["Q"],"chart_index":[{"Status":"Q"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Status":"Q"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Q"],"y":[6.0]}},"id":"cb682a5a-06af-4e44-9168-59a673dab062","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"65a1b1d4-11a7-43db-a203-16cbb43391bc","type":"ColumnDataSource"},"glyph":{"id":"aa206e7c-7cb7-478e-9d3a-0550ec839945","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"603c68aa-08cd-4c3b-8231-ae3e156b6a7c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9556b70f-454a-407a-9376-fb02e71626e8","type":"Rect"},{"attributes":{"data_source":{"id":"f77fb2e8-88a5-4801-a50e-2ca1bcbdc994","type":"ColumnDataSource"},"glyph":{"id":"5aa0fa82-26f2-4a4f-b306-0423849de6d8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"2acbdb94-5858-4d95-8395-8d49927f43de","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":7.55},"id":"1691f89b-a3dc-47a6-8926-0d28efdce1ea","typ ...

# %% [markdown]
# # Add Annotations on Your Plot
# * Customize your tools bar
#     * **pan**/**reset**/**save**/**crosshair**/**wheel_zoom**/**box_zoom**/**box_select**/**lasso_select**
#         * (e.g. : plot = figure(tools="pan,wheel_zoom,box_zoom,reset"))
#         * (e.g. : plot = figure(tools="", logo=None))
#     * **HoverTool**
# * Figure.XXXX() :
#     * **Circle**/**Line**/**Diamond**/** Square**/**Oval**
# * add_layout() :
#     * **Text**/**Arrow**

# %%
from bokeh.plotting import figure
from bokeh.models import HoverTool,Label, Arrow, VeeHead, OpenHead

# %%
hover = HoverTool(tooltips=[("(x,y)", "($x, $y)")])

# %%
Face = figure(width=400, height=240, tools=["hover,lasso_select"])
Face.circle([5] ,[-60], color='brown', size=200, radius=5, alpha=0.6, line_color='black')
Face.line(x=[1, 2, 3, 4, 5, 6, 7, 8, 9 ], y=[200, 350, 470, 530, 560,530, 470, 350, 200], color='black')
Face.circle([5], [0], color='red',size=60)
Face.circle([3.5, 6.5], [200, 200], color='Black',size=40)
Face.diamond([3.5, 6.5], [200, 200], color='gray',size=30, alpha=0.5)
Face.square([3.57, 6.57], [208, 208], color='white',size=3, alpha=1)
Face.oval([3, 7], [105, 105], fill_color='pink', line_color=None, height=50, width=2)

myText = Label(x=8.5, y=-60, text='Here')
Face.add_layout(myText)

myArrow_OH = Arrow(end=OpenHead(size=15, line_color="red", line_width=4),
                line_color="red", x_start=7.5, y_start=60, x_end=8.5, y_end=0)
Face.add_layout(myArrow_OH)

myArrow_VH = Arrow(end=VeeHead(size=15, fill_color="black", line_width=2),
                line_color="black", x_start=1.5, y_start=600, x_end=2.3, y_end=510)
Face.add_layout(myArrow_VH)

show(Face)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ee1bb714-7ecc-4235-a45b-f6a9b390ed90"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ee1bb714-7ecc-4235-a45b-f6a9b390ed90");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee1bb714-7ecc-4235-a45b-f6a9b390ed90");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee1bb714-7ecc-4235-a45b-f6a9b390ed90' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01628b83-a14f-4a84-a6d2-ffddb2a13989":{"roots":{"references":[{"attributes":{},"id":"891509c7-11ce-4c93-bad7-aeeeefa3f5a0","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"6704b0bf-3fcf-455f-ba9d-bea5b3f76586","type":"Square"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[5],"y":[0]}},"id":"72cf1803-5bf5-4ce0-88bb-7bcf8a47f4fb","type":"ColumnDataSource"},{"attributes":{},"id":"1b7f9bf3-cc4c-4287-a980-ff5e9cdcda4a","type":"BasicTicker"},{"attributes":{},"id":"73c83e9d-16b8-4354-a983-2d7f58ac1b09","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5f6b03df-4c57-4c25-872a-1a13b5ebc2f7","type":"HoverTool"},{"id":"46c7a2b4-4c2f-4604-ae7e-4e047808c1be","type":"LassoSelectTool"}]},"id":"89072cc2-28cb-4c10-b6d2-06d5b9e28b17","type":"Toolbar"},{"attributes":{},"id":"40311510-b3ce-4c14-a957-1973da2d9dde","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"white"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"01a00bf3-fcba-451f-b3cb-6e66f11454ab","type":"Square"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"7f56122b-05d8-4ac2-b5ba-afa294414077","type":"PolyAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":40},"x":{"field":"x"},"y":{"field":"y"}},"id":"631b7b23-087c-446b-84c2-4d9502cbfee3","type":"Circle"},{"attributes":{"data_source":{"id":"deeb5be9-07a1-457c-b456-563d112c83cc","type":"ColumnDataSource"},"glyph":{"id":"342dd6bd-2b99-401d-88fa-e153e968547c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"631b7b23-087c-446b-84c2-4d9502cbfee3","type":"Circle"},"selection_glyph":null},"id":"cb341498-a47d-49ce-ab80-a45e09c50673","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"line_alpha":{"value":0.5},"line_color":{"value":"gray"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e04edca-99c4-43b1-a9a6-7e6fc4e14945","type":"Diamond"},{"attributes":{"fill_color":{"value":"pink"},"height":{"units":"data","value":50},"line_color":{"value":null},"width":{"units":"data","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6935b33-7051-45d5-9a66-722d844190d2","type":"Oval"},{"attributes":{"data_source":{"id":"72cf1803-5bf5-4ce0-88bb-7bcf8a47f4fb","type":"ColumnDataSource"},"glyph":{"id":"2f80d39c-e342-41aa-9483-aedd5187c0f4","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"26d05cda-d62a-4e71-998b-67171e3bfd7c","type":"Circle"},"selection_glyph":null},"id":"9f868ea4-8bd2-4d9d-8c94-c8018194bc87","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3,7],"y":[105,105]}},"id":"74fd2ade-f664-420d-9338-8e57e08fc62b","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9aefb38-d047-4a12-a377-5179f35345f0","type":"Line"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"brown"},"line_alpha":{"value":0.6},"radius":{"units":"data","value":5},"size":{"units":"screen","value":200},"x":{"field":"x"},"y":{"field":"y"}},"id":"5db97521-cb90-458b-85b7-befe50eb8644","type":"Circle"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":4},"plot":null,"size":15},"id":"dc35244c-5316-42bd-ae6a-26b6db925aef","type":"OpenHead"},{"attributes":{"callback":null,"c ...

# %% [markdown]
# # Embed Plots in HTML

# %%
from bokeh.plotting import figure
from bokeh.resources import CDN
from bokeh.embed import components

# %% [markdown]
# * Get **js file** & **css file** informations, fill this in HTML **head part**

# %%
print(CDN.js_files)
print(CDN.css_files)
# Out:
# [u'https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js', u'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.6.min.js']
# [u'https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css', u'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.6.min.css']

# %% [markdown]
# * Create a plot and get **div** & **script** , fill this in HTML **body part**

# %%
html ="<!DOCTYPE HTML>"+ "\n"+\
          "<html>"+ "\n"+\
          "<head>"+ "\n"
print(html)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>

# %%
# script, div = components(hist, CDN)
# print(script)
# print(div)

# plots can be a single Bokeh Model, a list/tuple, or even a dictionary
plots = {'Histogram Plot': hist, 'Scatter Plot': scatter, 'Bar Plot': bar,
         'Bar Plot(Stack)': bar_stack, 'Box Plot': box, 'Face': Face}

script, div = components(plots)

html = "<!DOCTYPE HTML>"+ "\n"+\
        "<html>"+ "\n"+\
        "<head>"+ "\n"+\
        "<h> Create by Bokeh</h>"+ "\n"+\
        "<link href='{}' rel='stylesheet' type='text/css'></link>".format(CDN.css_files[0])+ "\n"+\
        "<link href='{}' rel='stylesheet' type='text/css'></link>".format(CDN.css_files[1])+ "\n"+\
        "<script src='{}'></script>".format(CDN.js_files[0])+ "\n"+\
        "<script src='{}'></script>".format(CDN.js_files[1])+ "\n"+\
        "</head>"+ "\n"+\
        "\n"+\
        "<body>"+ "\n"+\
        "{}, {}, {}, {}, {}, {}".format(div['Histogram Plot'],
                                        div['Scatter Plot'],
                                        div['Bar Plot'],
                                        div['Bar Plot(Stack)'],
                                        div['Box Plot'],
                                        div['Face']) + "\n"+ "\n"+\
        "<!-- Java Script for Plot-->"+\
        script+ "\n"+\
        "</body>"+ "\n"+\
        "</html>"
        
with open('Bokeh_Script.html', 'w') as html_file:
        html_file.write(html)

# %% [markdown]
# # Interactive in Notebook

# %% [markdown]
# * Widgets
#     * Slider
#     * RadioButtonGroup
#     * Select
#     * Button

# %%
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Button, RadioButtonGroup, Select, Slider

# %%
# Create widgets
slider = Slider(start=0, end=10, value=1, step=.1, title="Slider")
button_group = RadioButtonGroup(labels=["Olly", "Oil", "Ollier"], active=0)
select = Select(title="Who are you:", value="Olly", options=['Olly', 'Oil', 'Ollier', 'Olliver'])
button = Button(label="Hit Me~")

# Put the results in a row
show(widgetbox(button, slider, button_group, select, width=300))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fd9f6809-6cc7-4771-bbc1-14ba25b65eaa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fd9f6809-6cc7-4771-bbc1-14ba25b65eaa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fd9f6809-6cc7-4771-bbc1-14ba25b65eaa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fd9f6809-6cc7-4771-bbc1-14ba25b65eaa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cda8adf5-034f-403d-b80c-54ccf0df4a76":{"roots":{"references":[{"attributes":{"callback":null,"icon":null,"label":"Hit Me~"},"id":"f3d9654f-18f0-400e-bd81-65183420e384","type":"Button"},{"attributes":{"callback":null,"options":["Olly","Oil","Ollier","Olliver"],"title":"Who are you:","value":"Olly"},"id":"80c3ae57-8486-4ab6-a2c8-fd5e6c13e059","type":"Select"},{"attributes":{"children":[{"id":"f3d9654f-18f0-400e-bd81-65183420e384","type":"Button"},{"id":"e304cc68-6e4c-4cea-8da2-7e489153cde8","type":"Slider"},{"id":"e839dd19-abe3-4613-8df8-544d053912ca","type":"RadioButtonGroup"},{"id":"80c3ae57-8486-4ab6-a2c8-fd5e6c13e059","type":"Select"}],"width":300},"id":"1deab988-ff9a-4e9c-8dbd-308062c418d6","type":"WidgetBox"},{"attributes":{"callback":null,"end":10,"title":"Slider","value":1},"id":"e304cc68-6e4c-4cea-8da2-7e489153cde8","type":"Slider"},{"attributes":{"active":0,"callback":null,"labels":["Olly","Oil","Ollier"]},"id":"e839dd19-abe3-4613-8df8-544d053912ca","type":"RadioButtonGroup"}],"root_ids":["1deab988-ff9a-4e9c-8dbd-308062c418d6"]},"title":"Bokeh Application","version":"0.12.6"}};
#             var render_items = [{"docid":"cda8adf5-034f-403d-b80c-54ccf0df4a76","elementid":"fd9f6809-6cc7-4771-bbc1-14ba25b65eaa","modelid":"1deab988-ff9a-4e9c-8dbd-308062c418d6"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("fd9f6809-6cc7-4771-bbc1-14ba25b65eaa")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3f790598-7371-43ae-b8ee-38ffda13d8b3">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)
# Out:
# 3.141592653589793

# %%
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b379e44f-21cb-4e2e-9c6e-a2a64ae5ff4e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b379e44f-21cb-4e2e-9c6e-a2a64ae5ff4e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("b591e569-c5a1-4844-a5c0-835f82053e8e", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b379e44f-21cb-4e2e-9c6e-a2a64ae5ff4e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b379e44f-21cb-4e2e-9c6e-a2a64ae5ff4e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"867048b1-0b77-4a03-9e54-a06fbd833145":{"roots":{"references":[{"attributes":{"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"}},"id":"9e259923-38c1-4e51-b403-cc11d9107d59","type":"HelpTool"},{"attributes":{},"id":"20d64465-df96-4e3c-8f8a-8e0517b401ad","type":"BasicTicker"},{"attributes":{"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"}},"id":"c71338b1-5e97-464d-af03-550b90a8e7e5","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"19398626-40eb-4b9b-972a-40751ad3f91f","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"19398626-40eb-4b9b-972a-40751ad3f91f","type":"BoxAnnotation"},"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"}},"id":"9fa3ac0e-632b-43d5-93a2-f3ffa5e30d45","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"42c9cfdc-66f0-44cf-81f2-342f2ed5a58d","type":"BasicTickFormatter"},"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"},"ticker":{"id":"00576269-ed4c-4aa2-9823-b81888ee6d7b","type":"BasicTicker"}},"id":"62bde335-bbea-4ceb-93e8-4528b3e5b46f","type":"LinearAxis"},{"attributes":{"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"}},"id":"53b06df2-8c86-49fd-a05e-c00eed203006","type":"SaveTool"},{"attributes":{"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"}},"id":"0aff5b71-45b1-43a6-ac81-16a7d215244f","type":"ResetTool"},{"attributes":{"callback":null},"id":"faa8b25f-71a6-4ef7-959e-6d6529363401","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"a284a9c2-32af-4500-90c5-027abd3feadc","type":"ColumnDataSource"},{"attributes":{},"id":"70a2d764-6f12-4c85-8aaa-a981268e5950","type":"ToolEvents"},{"attributes":{"data_source":{"id":"a284a9c2-32af-4500-90c5-027abd3feadc","type":"ColumnDataSource"},"glyph":{"id":"27901366-ffdb-42bf-b11b-4ab412ee3866","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"15625e97-c01b-43a1-a762-3edb390a0012","type":"Line"},"selection_glyph":null},"id":"460e8272-b188-4f64-b4c8-484946838c47","type":"GlyphRenderer"},{"attributes":{},"id":"c41be3c4-0fb1-451d-8703-df10d7a8e0d4","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c71338b1-5e97-464d-af03-550b90a8e7e5","type":"PanTool"},{"id":"90124cb2-be59-43ca-b978-173f5cdfcaee","type":"WheelZoomTool"},{"id":"9fa3ac0e-632b-43d5-93a2-f3ffa5e30d45","type":"BoxZoomTool"},{"id":"53b06df2-8c86-49fd-a05e-c00eed203006","type":"SaveTool"},{"id":"0aff5b71-45b1-43a6-ac81-16a7d215244f","type":"ResetTool"},{"id":"9e259923-38c1-4e51-b403-cc11d9107d59","type":"HelpTool"}]},"id":"c075f998-a73c-4158-90b8-8263eee7eee5","type":"Toolbar"},{"attributes":{"plot":null,"text":"simple line example"},"id":"b2ef1185-6485-4d13-ae4a-ccc8144c218d","type":"Title"},{"attributes":{},"id":"c75cd145-c1a5-4460-ba5b-c83ee9b929db","type":"BasicTickFormatter"},{"attributes":{},"id":"42c9cfdc-66f0-44cf-81f2-342f2ed5a58d","type":"BasicTickFormatter"},{"attributes":{},"id":"00576269-ed4c-4aa2-9823-b81888ee6d7b","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"27901366-ffdb-42bf-b11b-4ab412ee3866","type":"Line"},{"attributes":{"plot":{"id":"24b5ba71-229a-4f82-b87b-083d6b567484","subtype":"Figure","type":"Plot"}},"id":"90124cb2-be59-43ca-b978-173f5cdfcaee","type":"WheelZoomTool"},{"attributes":{"d ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[49]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,5), phi=(0, 20, 0.1))
